# %% [markdown]
# # Importação das bibliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dados = pd.read_csv('csv_limpo.csv')
dados
# Out:
#     Rank  Actual gross  Adjusted gross (in 2022 dollars)        Artist  \
# 0      1   780000000.0                       780000000.0  Taylor Swift
# 1      2   579800000.0                       579800000.0       Beyoncé
# 2      3   411000000.0                       560622615.0       Madonna
# 3      4   397300000.0                       454751555.0          Pink
# 4      5   345675146.0                       402844849.0  Taylor Swift
# 5      6   305158363.0                       388978496.0       Madonna
# 6      7   280000000.0                       381932682.0   Celine Dion
# 7      8   257600000.0                       257600000.0          Pink
# 8      9   256084556.0                       312258401.0       Beyoncé
# 9     10   250400000.0                       309141878.0  Taylor Swift
# 10    11   229100000.0                       283202896.0       Beyoncé
# 11    12   227400000.0                       295301479.0     Lady Gaga
# 12    13   204000000.0                       251856802.0    Katy Perry
# 13    14   200000000.0                       299676265.0          Cher
# 14    15   194000000.0                       281617035.0       Madonna
# 15    16   184000000.0                       227452347.0          Pink
# 16    17   170000000.0                       213568571.0     Lady Gaga
# 17    18   169800000.0                       207046755.0       Madonna
# 18    19   167700000.0                       204486106.0         Adele
# 19    20   150000000.0                       185423109.0  Taylor Swift
#
#                          Tour title  Shows  Average gross  Start year  \
# 0                    The Eras Tour      56     13928571.0        2023
# 1            Renaissance World Tour     56     10353571.0        2023
# 2              Sticky & Sweet Tour      85      4835294.0        2008
# 3       Beautiful Trauma World Tour    156      2546795.0        2018
# 4           Reputation Stadium Tour     53      6522173.0        2018
# 5                     The MDNA Tour     88      3467709.0        2012
# 6         Taking Chances World Tour    131      2137405.0        2008
# 7                  Summer Carnival      41      6282927.0        2023
# 8          The Formation World Tour     49      5226215.0        2016
# 9               The 1989 World Tour     85      2945882.0        2015
# 10   The Mrs Carter Show World Tour    132      1735606.0        2013
# 11           The Monster Ball Tour     203      1118227.0        2009
# 12             Prismatic World Tour    151      1350993.0        2014
# 13  Living Proof The Farewell Tour     325       615385.0        2002
# 14                 Confessions Tour     60      3233333.0        2006
# 15        The Truth About Love Tour    142      1295775.0        2013
# 16               Born This Way Ball     98      1734694.0        2012
# 17                 Rebel Heart Tour     82      2070732.0        2015
# 18                  Adele Live 2016    121      1385950.0        2016
# 19                     The Red Tour     86      1744186.0        2013
#
#     End year
# 0       2024
# 1       2023
# 2       2009
# 3       2019
# 4       2018
# 5       2012
# 6       2009
# 7       2024
# 8       2016
# 9       2015
# 10      2014
# 11      2011
# 12      2015
# 13      2005
# 14      2006
# 15      2014
# 16      2013
# 17      2016
# 18      2017
# 19      2014

# %% [markdown]
# # Questões:
#
# Q1 - Qual é a artista que mais aparece nessa lista e possui a maior média de seu faturamento bruto (Actual gross)?

# %%
artista_mais_aparicoes = dados.value_counts('Artist', ascending=False).head(1) # Contagem da artista com mais aparições
artista_mais_aparicoes
# Out:
# Artist
# Taylor Swift    4
# Name: count, dtype: int64

# %%
media_artista = dados.groupby('Artist')['Actual gross'].mean() # Cálculo da média de faturamento das artistas
artista_maior_media = media_artista.sort_values(ascending=False).head(1) # Isolando a artista com maior média
artista_maior_media
# Out:
# Artist
# Taylor Swift    381518786.5
# Name: Actual gross, dtype: float64

# %%
# Retorno da solução:
print(f'Q1:\n\n--- A artista com mais aparições é {artista_mais_aparicoes.index[0]} com {artista_mais_aparicoes.iloc[0]}, possuindo a média de faturamento bruto de ${artista_maior_media.values[0]:.2f}\n')
# Out:
# Q1:
#
# --- A artista com mais aparições é Taylor Swift com 4, possuindo a média de faturamento bruto de $381518786.50

# %% [markdown]
# Q2 - Das turnês que aconteceram dentro de um ano, qual a turnê com a maior média de faturamento bruto (Average gross)?

# %%
turne_um_ano = dados[dados['Start year'] == dados['End year']] # Separando turnês de apenas um ano
turne_um_ano
# Out:
#     Rank  Actual gross  Adjusted gross (in 2022 dollars)        Artist  \
# 1      2   579800000.0                       579800000.0       Beyoncé
# 4      5   345675146.0                       402844849.0  Taylor Swift
# 5      6   305158363.0                       388978496.0       Madonna
# 8      9   256084556.0                       312258401.0       Beyoncé
# 9     10   250400000.0                       309141878.0  Taylor Swift
# 14    15   194000000.0                       281617035.0       Madonna
#
#                   Tour title  Shows  Average gross  Start year  End year
# 1     Renaissance World Tour     56     10353571.0        2023      2023
# 4    Reputation Stadium Tour     53      6522173.0        2018      2018
# 5              The MDNA Tour     88      3467709.0        2012      2012
# 8   The Formation World Tour     49      5226215.0        2016      2016
# 9        The 1989 World Tour     85      2945882.0        2015      2015
# 14          Confessions Tour     60      3233333.0        2006      2006

# %%
maior_media_turne = turne_um_ano.sort_values('Average gross', ascending=False).head(1) # Separando a média
maior_media_turne
# Out:
#    Rank  Actual gross  Adjusted gross (in 2022 dollars)   Artist  \
# 1     2   579800000.0                       579800000.0  Beyoncé
#
#                Tour title  Shows  Average gross  Start year  End year
# 1  Renaissance World Tour     56     10353571.0        2023      2023

# %%
# Retorno da solução:
print(f'Q2:\n\n--- Das turnes que aconteceram em um ano, a turnê com a  maior media de faturamento bruto é {maior_media_turne["Tour title"].values[0]} com uma média de ${maior_media_turne["Average gross"].values[0]:.2f}\n')
# Out:
# Q2:
#
# --- Das turnes que aconteceram em um ano, a turnê com a maior media de faturamento bruto é Renaissance World Tour com uma média de $10353571.00

# %% [markdown]
# Q3 - Quais são as 3 turnês que possuem o show (unitário) mais lucrativo? Cite também o nome de cada artista e o valor por show.
# Utilize a coluna "Adjusted gross (in 2022 dollars)". Caso necessário, crie uma coluna nova para essa conta.

# %%
dados['Gain per show'] = dados['Adjusted gross (in 2022 dollars)'] / dados['Shows'] # Criando nova coluna com o cálculo da divisão
dados
# Out:
#     Rank  Actual gross  Adjusted gross (in 2022 dollars)        Artist  \
# 0      1   780000000.0                       780000000.0  Taylor Swift
# 1      2   579800000.0                       579800000.0       Beyoncé
# 2      3   411000000.0                       560622615.0       Madonna
# 3      4   397300000.0                       454751555.0          Pink
# 4      5   345675146.0                       402844849.0  Taylor Swift
# 5      6   305158363.0                       388978496.0       Madonna
# 6      7   280000000.0                       381932682.0   Celine Dion
# 7      8   257600000.0                       257600000.0          Pink
# 8      9   256084556.0                       312258401.0       Beyoncé
# 9     10   250400000.0                       309141878.0  Taylor Swift
# 10    11   229100000.0                       283202896.0       Beyoncé
# 11    12   227400000.0                       295301479.0     Lady Gaga
# 12    13   204000000.0                       251856802.0    Katy Perry
# 13    14   200000000.0                       299676265.0          Cher
# 14    15   194000000.0                       281617035.0       Madonna
# 15    16   184000000.0                       227452347.0          Pink
# 16    17   170000000.0                       213568571.0     Lady Gaga
# 17    18   169800000.0                       207046755.0       Madonna
# 18    19   167700000.0                       204486106.0         Adele
# 19    20   150000000.0                       185423109.0  Taylor Swift
#
#                          Tour title  Shows  Average gross  Start year  \
# 0                    The Eras Tour      56     13928571.0        2023
# 1            Renaissance World Tour     56     10353571.0        2023
# 2              Sticky & Sweet Tour      85      4835294.0        2008
# 3       Beautiful Trauma World Tour    156      2546795.0        2018
# 4           Reputation Stadium Tour     53      6522173.0        2018
# 5                     The MDNA Tour     88      3467709.0        2012
# 6         Taking Chances World Tour    131      2137405.0        2008
# 7                  Summer Carnival      41      6282927.0        2023
# 8          The Formation World Tour     49      5226215.0        2016
# 9               The 1989 World Tour     85      2945882.0        2015
# 10   The Mrs Carter Show World Tour    132      1735606.0        2013
# 11           The Monster Ball Tour     203      1118227.0        2009
# 12             Prismatic World Tour    151      1350993.0        2014
# 13  Living Proof The Farewell Tour     325       615385.0        2002
# 14                 Confessions Tour     60      3233333.0        2006
# 15        The Truth About Love Tour    142      1295775.0        2013
# 16               Born This Way Ball     98      1734694.0        2012
# 17                 Rebel Heart Tour     82      2070732.0        2015
# 18                  Adele Live 2016    121      1385950.0        2016
# 19                     The Red Tour     86      1744186.0        2013
#
#     End year  Gain per show
# 0       2024   1.392857e+07
# 1       2023   1.035357e+07
# 2       2009   6.595560e+06
# 3       2019   2.915074e+06
# 4       2018   7.600846e+06
# 5       2012   4.420210e+06
# 6       2009   2.915517e+06
# 7       2024   6.282927e+06
# 8       2016   6.372620e+06
# 9       2015   3.636963e+06
# 10      2014   2.145476e+06
# 11      2011   1.454687e+06
# 12      2015   1.667926e+06
# 13      2005   9.220808e+05
# 14      2006   4.693617e+06
# 15      2014   1.601777e+06
# 16      2013   2.179271e+06
# 17      2016   2.524960e+06
# 18      2017   1.689968e+06
# 19      2014   2.156083e+06

# %%
shows_mais_lucrativos = dados.sort_values('Gain per show', ascending=False).head(3) # Separando os shows com mais lucro
shows_mais_lucrativos
# Out:
#    Rank  Actual gross  Adjusted gross (in 2022 dollars)        Artist  \
# 0     1   780000000.0                       780000000.0  Taylor Swift
# 1     2   579800000.0                       579800000.0       Beyoncé
# 4     5   345675146.0                       402844849.0  Taylor Swift
#
#                 Tour title  Shows  Average gross  Start year  End year  \
# 0           The Eras Tour      56     13928571.0        2023      2024
# 1   Renaissance World Tour     56     10353571.0        2023      2023
# 4  Reputation Stadium Tour     53      6522173.0        2018      2018
#
#    Gain per show
# 0   1.392857e+07
# 1   1.035357e+07
# 4   7.600846e+06

# %%
# Retorno da solução:
print('Q3:\n\n--- As três turnês que possuem o show mais lucrativo são:')
for i, row in shows_mais_lucrativos.iterrows():
    print(f'- A turnê {row["Tour title"]}, da artista {row["Artist"]} com um lucro por show de ${row["Gain per show"]:.2f}')
# Out:
# Q3:
#
# --- As três turnês que possuem o show mais lucrativo são:
# - A turnê The Eras Tour , da artista Taylor Swift com um lucro por show de $13928571.43
# - A turnê Renaissance World Tour, da artista Beyoncé com um lucro por show de $10353571.43
# - A turnê Reputation Stadium Tour, da artista Taylor Swift com um lucro por show de $7600846.21

# %% [markdown]
# Q4 - Para a artista que mais aparece nessa lista e que tenha o maior somatório de faturamento bruto, crie um gráfico de linhas que mostra o faturamento por ano da turnê (use a coluna Start Year). Apenas os anos com turnês.

# %%
faturamento_artista = dados.groupby('Artist')['Actual gross'].sum() # Somando o faturamento das artistas
faturamento_artista.sort_values(ascending=False)
# Out:
# Artist
# Taylor Swift    1.526075e+09
# Madonna         1.079958e+09
# Beyoncé         1.064985e+09
# Pink            8.389000e+08
# Lady Gaga       3.974000e+08
# Celine Dion     2.800000e+08
# Katy Perry      2.040000e+08
# Cher            2.000000e+08
# Adele           1.677000e+08
# Name: Actual gross, dtype: float64

# %%
artista_maior_faturamento = faturamento_artista.sort_values(ascending=False).head(1) # Separando a artista com maior faturamento
artista_maior_faturamento
# Out:
# Artist
# Taylor Swift    1.526075e+09
# Name: Actual gross, dtype: float64

# %%
dados_artista = dados[dados['Artist'] == 'Taylor Swift'] # Dividindo os dados desta artista
dados_artista
# Out:
#     Rank  Actual gross  Adjusted gross (in 2022 dollars)        Artist  \
# 0      1   780000000.0                       780000000.0  Taylor Swift
# 4      5   345675146.0                       402844849.0  Taylor Swift
# 9     10   250400000.0                       309141878.0  Taylor Swift
# 19    20   150000000.0                       185423109.0  Taylor Swift
#
#                  Tour title  Shows  Average gross  Start year  End year  \
# 0            The Eras Tour      56     13928571.0        2023      2024
# 4   Reputation Stadium Tour     53      6522173.0        2018      2018
# 9       The 1989 World Tour     85      2945882.0        2015      2015
# 19             The Red Tour     86      1744186.0        2013      2014
#
#     Gain per show
# 0    1.392857e+07
# 4    7.600846e+06
# 9    3.636963e+06
# 19   2.156083e+06

# %%
faturamento_ano = dados_artista.groupby('Start year')['Actual gross'].sum().sort_index() # Somando o faturamento da artista para implantar no gráfico
faturamento_ano
# Out:
# Start year
# 2013    150000000.0
# 2015    250400000.0
# 2018    345675146.0
# 2023    780000000.0
# Name: Actual gross, dtype: float64

# %%
# Implantação do gráfico(solução):
plt.figure(figsize=(8,4)) # Tamanho
plt.title('Faturamento por ano das turnês de Taylor Swift') #Título do gráfico
plt.plot(faturamento_ano.index, faturamento_ano.values, color='purple', marker='o') # Plot do gráfico
plt.xlabel('Ano') # Legenda Eixo X
plt.ylabel('Faturamento Bruto ($) em Milhões') # Legenda Eixo Y
plt.ticklabel_format(style='sci', axis='y', scilimits=(6,6)) # Formatação do número eixo Y
plt.tight_layout() # Layout justificado
plt.grid(True) # Ativação da 'grade' no gráfico
plt.savefig('Q4.png') # Salvar figura 
plt.show()

# %% [markdown]
# Q5 - Faça um gráfico de colunas demonstrando as 5 artistas com mais shows na lista.

# %%
artistas_mais_shows = dados.groupby('Artist')['Shows'].sum().sort_values(ascending=False).head(5) # Separando artistas com mais shows
artistas_mais_shows
# Out:
# Artist
# Pink            339
# Cher            325
# Madonna         315
# Lady Gaga       301
# Taylor Swift    280
# Name: Shows, dtype: int64

# %%
#Implantação do gráfico(solução):
fig, ax = plt.subplots(figsize=(8, 5)) # Tamanho
barras = ax.bar(artistas_mais_shows.index, artistas_mais_shows.values, color='orange') # Plot do gráfico com nome de variável
plt.title('Artistas com mais shows') # Título do gráfico
plt.xlabel('Nome das artistas') # Legenda Eixo X
plt.ylabel('Quantidade de Shows') # Legenda Eixo Y
ax.bar_label(barras, label_type='center', color='white', padding=3) # Números das colunas
plt.xticks(rotation=2) # Rotação dos itens Eixo X
plt.tight_layout() # Layout justificado
plt.savefig('Q5.png') # Salvar figura 
plt.show()
